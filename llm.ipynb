# %%
# !pip install -r 'requirements.txt'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch==2.2.2 in /home/abhin/.local/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: triton==2.2.0 in /home/abhin/.local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: bitsandbytes==0.43.2 in /home/abhin/.local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.43.2)
# Requirement already satisfied: transformers==4.40.2 in /home/abhin/.local/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (4.40.2)
# Requirement already satisfied: huggingface_hub==0.23.2 in /home/abhin/.local/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (0.23.2)
# Requirement already satisfied: accelerate==0.30.1 in /home/abhin/.local/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (0.30.1)
# Requirement already satisfied: datasets==2.19.1 in /home/abhin/.local/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (2.19.1)
# Requirement already satisfied: peft==0.10.0 in /home/abhin/.local/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (0.10.0)
# Requirement already satisfied: trl==0.8.6 in /home/abhin/.local/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (0.8.6)
# Requirement already satisfied: python-dotenv in /home/abhin/.local/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (1.2.1)
# Requirement already satisfied: rich in /home/abhin/.local/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (14.3.3)
# Collecting pyTelegramBotAPI
#   Downloading pytelegrambotapi-4.31.0-py3-none-any.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.2/304.2 KB 1.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (11.4.5.107)
# Requirement already satisfied: fsspec in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (2024.3.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (10.3.2.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (2.19.3)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (11.0.2.54)
# Requirement already satisfied: filelock in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (3.24.3)
# Requirement already satisfied: networkx in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: sympy in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (12.1.3.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch==2.2.2->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/abhin/.local/lib/python3.10/site-packages (from torch==2.2.2->-r requirements.txt (line 1)) (12.1.0.106)
# Requirement already satisfied: numpy in /home/abhin/.local/lib/python3.10/site-packages (from bitsandbytes==0.43.2->-r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: requests in /home/abhin/.local/lib/python3.10/site-packages (from transformers==4.40.2->-r requirements.txt (line 4)) (2.32.5)
# Requirement already satisfied: safetensors>=0.4.1 in /home/abhin/.local/lib/python3.10/site-packages (from transformers==4.40.2->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers==4.40.2->-r requirements.txt (line 4)) (5.4.1)
# Requirement already satisfied: tqdm>=4.27 in /home/abhin/.local/lib/python3.10/site-packages (from transformers==4.40.2->-r requirements.txt (line 4)) (4.67.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/abhin/.local/lib/python3.10/site-packages (from transformers==4.40.2->-r requirements.txt (line 4)) (0.19.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/abhin/.local/lib/python3.10/site-packages (from transformers==4.40.2->-r requirements.txt (line 4)) (2026.2.19)
# Requirement already satisfied: packaging>=20.0 in /home/abhin/.local/lib/python3.10/site-packages (from transformers==4.40.2->-r requirements.txt (line 4)) (26.0)
# Requirement already satisfied: psutil in /home/abhin/.local/lib/python3.10/site-packages (from accelerate==0.30.1->-r requirements.txt (line 6)) (7.2.2)
# Requirement already satisfied: xxhash in /home/abhin/.local/lib/python3.10/site-packages (from datasets==2.19.1->-r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: aiohttp in /home/abhin/.local/lib/python3.10/site-packages (from datasets==2.19.1->-r requirements.txt (line 7)) (3.13.3)
# Requirement already satisfied: multiprocess in /home/abhin/.local/lib/python3.10/site-packages (from datasets==2.19.1->-r requirements.txt (line 7)) (0.70.16)
# Requirement already satisfied: pandas in /home/abhin/.local/lib/python3.10/site-packages (from datasets==2.19.1->-r requirements.txt (line 7)) (2.3.3)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/abhin/.local/lib/python3.10/site-packages (from datasets==2.19.1->-r requirements.txt (line 7)) (23.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/abhin/.local/lib/python3.10/site-packages (from datasets==2.19.1->-r requirements.txt (line 7)) (0.3.8)
# Requirement already satisfied: pyarrow-hotfix in /home/abhin/.local/lib/python3.10/site-packages (from datasets==2.19.1->-r requirements.txt (line 7)) (0.7)
# Requirement already satisfied: tyro>=0.5.11 in /home/abhin/.local/lib/python3.10/site-packages (from trl==0.8.6->-r requirements.txt (line 9)) (1.0.8)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/abhin/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.2->-r requirements.txt (line 1)) (12.9.86)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/abhin/.local/lib/python3.10/site-packages (from rich->-r requirements.txt (line 11)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/abhin/.local/lib/python3.10/site-packages (from rich->-r requirements.txt (line 11)) (2.19.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/abhin/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.1->-r requirements.txt (line 7)) (5.0.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/abhin/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.1->-r requirements.txt (line 7)) (0.4.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/abhin/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.1->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/abhin/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.1->-r requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/abhin/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.1->-r requirements.txt (line 7)) (1.22.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/abhin/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.1->-r requirements.txt (line 7)) (6.7.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/abhin/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.1->-r requirements.txt (line 7)) (25.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/abhin/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.1->-r requirements.txt (line 7)) (2.6.1)
# Requirement already satisfied: mdurl~=0.1 in /home/abhin/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 11)) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/abhin/.local/lib/python3.10/site-packages (from requests->transformers==4.40.2->-r requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->transformers==4.40.2->-r requirements.txt (line 4)) (1.26.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->transformers==4.40.2->-r requirements.txt (line 4)) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->transformers==4.40.2->-r requirements.txt (line 4)) (2020.6.20)
# Requirement already satisfied: docstring-parser>=0.15 in /home/abhin/.local/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.8.6->-r requirements.txt (line 9)) (0.17.0)
# Requirement already satisfied: typeguard>=4.0.0 in /home/abhin/.local/lib/python3.10/site-packages (from tyro>=0.5.11->trl==0.8.6->-r requirements.txt (line 9)) (4.5.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/abhin/.local/lib/python3.10/site-packages (from pandas->datasets==2.19.1->-r requirements.txt (line 7)) (2025.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->datasets==2.19.1->-r requirements.txt (line 7)) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/abhin/.local/lib/python3.10/site-packages (from pandas->datasets==2.19.1->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/abhin/.local/lib/python3.10/site-packages (from sympy->torch==2.2.2->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.19.1->-r requirements.txt (line 7)) (1.16.0)
# Installing collected packages: pyTelegramBotAPI
# Successfully installed pyTelegramBotAPI-4.31.0

# %%
from huggingface_hub import login
import os
import gc 
import torch
from transformers import AutoModelForCausalLM,AutoTokenizer,BitsAndBytesConfig,TrainingArguments
from peft import LoraConfig,get_peft_model,prepare_model_for_kbit_training,PeftModel,TaskType
from datasets import load_dataset
from trl import SFTTrainer
from dotenv import load_dotenv

# %%
load_dotenv()
token=os.getenv('hf_token')
login(token)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /home/abhin/.cache/huggingface/token
# Login successful

# %%
model_name = "meta-llama/Meta-Llama-3-8B-Instruct"
dataset_path='dataset/extended_dataset.jsonl'
output_dir='llama-output'
adapter_save_path='temp-adapters'
merged_save_path='llama-8b-merged-ultra'

# %%
GPU_VRAM       = "5.5GiB"   
CPU_RAM        = "7.2GiB"

# %%
MAX_SEQ_LEN    = 512        
LORA_R         = 16         
LORA_ALPHA     = 32         
EPOCHS         = 5
LEARNING_RATE  = 2e-4

# %%
bnb_config=BitsAndBytesConfig(load_in_4bit=True,bnb_4bit_quant_type='nf4',
                              bnb_4bit_compute_dtype=torch.float16,bnb_4bit_use_double_quant=True)

# %%
print("📥 Loading model with GPU + CPU memory split...")
max_memory = {
    0: GPU_VRAM,     
    "cpu": CPU_RAM,   
}
# Out:
# 📥 Loading model with GPU + CPU memory split...

# %%
print("📥 Loading Llama-3-8B base model...")
model=AutoModelForCausalLM.from_pretrained(model_name,max_memory=max_memory,quantization_config=bnb_config,device_map='auto',trust_remote_code=True,low_cpu_mem_usage=True,torch_dtype=torch.float16)
# Out:
# 📥 Loading Llama-3-8B base model...
# /home/abhin/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 4/4 [00:15<00:00,  3.82s/it]

# %%
tokenizer=AutoTokenizer.from_pretrained(model_name,trust_remote_code=True)
tokenizer.pad_token=tokenizer.eos_token
tokenizer.padding_side='right'
tokenizer.model_max_length = MAX_SEQ_LEN
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
print("\n📍 Layer device map:")
device_counts = {}
for name, param in model.named_parameters():
    device = str(param.device)
    device_counts[device] = device_counts.get(device, 0) + 1
for device, count in device_counts.items():
    print(f"  {device}: {count} parameter tensors")
print()
# Out:
# 📍 Layer device map:
#   cuda:0: 291 parameter tensors

# %%
print(f"loading the dataset from {dataset_path}")
raw_dataset=load_dataset('json',data_files=dataset_path,split='train')
dataset=raw_dataset.train_test_split(test_size=0.2,seed=42)
# Out:
# loading the dataset from dataset/extended_dataset.jsonl

# %%
def formatting_func(example):
    """Alpaca-style prompt format — handles both single and batched examples"""
    
    # Handle batched input (list of examples)
    if isinstance(example["instruction"], list):
        outputs = []
        for instruction, inp, output in zip(
            example["instruction"],
            example["input"],
            example["output"]
        ):
            if inp and inp.strip():
                text = (
                    f"### Instruction:\n{instruction}\n\n"
                    f"### Input:\n{inp}\n\n"
                    f"### Output:\n{output}"
                )
            else:
                text = (
                    f"### Instruction:\n{instruction}\n\n"
                    f"### Output:\n{output}"
                )
            outputs.append(text)
        return outputs

    # Handle single example
    instruction = example.get("instruction", "")
    inp         = example.get("input", "")
    output      = example.get("output", "")

    if inp and inp.strip():
        return (
            f"### Instruction:\n{instruction}\n\n"
            f"### Input:\n{inp}\n\n"
            f"### Output:\n{output}"
        )
    else:
        return (
            f"### Instruction:\n{instruction}\n\n"
            f"### Output:\n{output}"
        )

# %%
model = prepare_model_for_kbit_training(
    model,
    use_gradient_checkpointing=True,
)

# %%
; # ============================================================
; # STEP 7 — TRAINING ARGUMENTS
; # ============================================================
; training_args = TrainingArguments(
;     output_dir=output_dir,

;     # Batch settings — safe for 6GB
;     per_device_train_batch_size=1,
;     gradient_accumulation_steps=8,       # Effective batch size = 8
;     per_device_eval_batch_size=1,

;     # Training length
;     num_train_epochs=EPOCHS,
;     warmup_steps=10,
;     learning_rate=LEARNING_RATE,
;     max_grad_norm=0.3,                   # Gradient clipping for stability

;     # Precision
;     fp16=True,
;     bf16=False,                          # BF16 only on Ampere+ (RTX 30xx/40xx)

;     # Memory savers
;     gradient_checkpointing=True,         # Trades compute for memory
;     optim="paged_adamw_8bit",            # 8-bit optimizer saves ~400MB vs 32-bit
;     dataloader_num_workers=0,            # Avoids multiprocessing memory issues

;     # Logging & saving
;     logging_steps=5,
;     eval_strategy="steps",
;     eval_steps=50,
;     save_strategy="steps",
;     save_steps=50,
;     save_total_limit=2,                  # Keep only best 2 checkpoints
;     load_best_model_at_end=True,
;     report_to="none",
; )

; # ============================================================
; # STEP 8 — TRAIN
; # ============================================================
; trainer = SFTTrainer(
;     model=model,
;     train_dataset=dataset["train"],
;     eval_dataset=dataset["test"],
;     formatting_func=formatting_func,
;     max_seq_length=MAX_SEQ_LEN,
;     args=training_args,
; )

; # Show VRAM before training starts
; if torch.cuda.is_available():
;     allocated = torch.cuda.memory_allocated(0) / 1024**3
;     reserved  = torch.cuda.memory_reserved(0) / 1024**3
;     print(f"💾 VRAM before training: {allocated:.2f}GB allocated / {reserved:.2f}GB reserved")

; print("🚀 Starting QLoRA fine-tuning...\n")
; trainer.train()

; print("\n💾 Saving adapters...")
; trainer.model.save_pretrained(adapter_save)
; tokenizer.save_pretrained(adapter_save)
; print(f"  Adapters saved to: {adapter_save}")

; # ============================================================
; # STEP 9 — MERGE ADAPTERS INTO BASE MODEL (ON CPU)
; # ============================================================
; print("\n🧹 Clearing VRAM for merge step...")
; del model
; del trainer
; gc.collect()
; torch.cuda.empty_cache()

; if torch.cuda.is_available():
;     free = (torch.cuda.get_device_properties(0).total_memory
;             - torch.cuda.memory_allocated(0)) / 1024**3
;     print(f"  VRAM freed. Available: {free:.2f}GB")

; print("\n🔄 Loading base model on CPU for merging...")
; print("  (This uses ~16GB system RAM — may take a few minutes)")

; base_model = AutoModelForCausalLM.from_pretrained(
;     model_name,
;     low_cpu_mem_usage=True,
;     torch_dtype=torch.float16,
;     device_map="cpu",              # Always merge on CPU to avoid OOM
; )

; print("🔗 Applying LoRA adapters...")
; model_to_merge = PeftModel.from_pretrained(base_model, adapter_save)

; print("⚙️  Merging weights (this takes a few minutes)...")
; merged_model = model_to_merge.merge_and_unload()

; print(f"✅ Saving merged model to: {merged_save}")
; merged_model.save_pretrained(merged_save, safe_serialization=True)
; tokenizer.save_pretrained(merged_save)

; # Clean up CPU RAM
; del base_model, model_to_merge, merged_model
; gc.collect()
; print("  Merged model saved successfully.\n")

; # ============================================================
; # STEP 10 — CONVERT TO GGUF (llama.cpp)
; # ============================================================
; def run(cmd, desc=""):
;     """Run a shell command and stream output"""
;     if desc:
;         print(f"  {desc}")
;     result = subprocess.run(cmd, shell=True, text=True)
;     if result.returncode != 0:
;         print(f"  ⚠️  Command failed: {cmd}")
;         return False
;     return True

; print("📥 Setting up llama.cpp...")

; if not os.path.exists("llama.cpp"):
;     run("git clone https://github.com/ggerganov/llama.cpp", "Cloning llama.cpp...")

; run("pip install -r llama.cpp/requirements.txt -q", "Installing llama.cpp requirements...")

; # Build llama.cpp (Linux/Mac)
; if sys.platform != "win32":
;     run("cd llama.cpp && make -j4", "Building llama.cpp...")
; else:
;     # Windows — use cmake
;     run(
;         "cd llama.cpp && cmake -B build && cmake --build build --config Release",
;         "Building llama.cpp (Windows)..."
;     )

; print("\n🔄 Converting to FP16 GGUF...")
; run(
;     f"python llama.cpp/convert_hf_to_gguf.py {merged_save} "
;     f"--outfile {fp16_gguf} --outtype f16",
;     f"Output: {fp16_gguf}"
; )

; print("\n🗜️  Quantising to Q4_K_M...")
; quantize_bin = "./llama.cpp/llama-quantize" if sys.platform != "win32" \
;                else ".\\llama.cpp\\build\\bin\\Release\\llama-quantize.exe"
; run(
;     f"{quantize_bin} {fp16_gguf} {final_gguf} Q4_K_M",
;     f"Output: {final_gguf}"
; )

; # ============================================================
; # STEP 11 — CLEANUP INTERMEDIATE FILES
; # ============================================================
; if os.path.exists(final_gguf):
;     print("\n🧹 Cleaning up intermediate files...")
;     if os.path.exists(fp16_gguf):
;         os.remove(fp16_gguf)
;         print(f"  Deleted: {fp16_gguf}")
;     if os.path.exists(merged_save):
;         import shutil
;         shutil.rmtree(merged_save)
;         print(f"  Deleted: {merged_save}/")
;     if os.path.exists(adapter_save):
;         import shutil
;         shutil.rmtree(adapter_save)
;         print(f"  Deleted: {adapter_save}/")

;     final_size = os.path.getsize(final_gguf) / 1024**3
;     print(f"\n🎉 Done! Final model: {final_gguf} ({final_size:.1f} GB)")
;     print("\n📋 To run with llama.cpp:")
;     print(f"  ./llama.cpp/llama-cli -m {final_gguf} -p 'Your prompt here' -n 200")
;     print("\n📋 To run with Ollama:")
;     print(f"  ollama create my-llama -f Modelfile  # (point Modelfile to {final_gguf})")
; else:
;     print("\n⚠️  GGUF conversion may have failed.")
;     print(f"  Check if {fp16_gguf} exists and re-run the quantize step manually.")
;     print(f"  Merged HF model is still available at: {merged_save}")

; # ============================================================
; ; # MEMORY TIPS (printed at end for reference)?
; # ============================================================
; print("""
; ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
; 💡 If you hit OOM errors, try these in order:
;    1. Lower MAX_SEQ_LEN from 512 → 256
;    2. Lower LORA_R from 16 → 8
;    3. Lower CPU_RAM if system RAM is limited
;    4. Remove "k_proj"/"o_proj" from target_modules
;    5. Set GPU_VRAM to "5GiB" (more conservative)
; ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
; """)

# %%
peft_config = LoraConfig(
    task_type=TaskType.CAUSAL_LM,
    r=LORA_R,
    lora_alpha=LORA_ALPHA,
    lora_dropout=0.05,
    # q_proj + v_proj = minimum set for good results on 6GB
    # Add "k_proj", "o_proj" if you have headroom
    target_modules=["q_proj", "v_proj"],
    bias="none",
)

# %%
model = get_peft_model(model, peft_config)

print("📐 Trainable parameters:")
model.print_trainable_parameters()
print()
# Out:
# 📐 Trainable parameters:
# trainable params: 6,815,744 || all params: 8,037,076,992 || trainable%: 0.08480376642881861

# %%
training_args = TrainingArguments(
    output_dir=output_dir,

    # Batch settings — safe for 6GB
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,       # Effective batch size = 8
    per_device_eval_batch_size=1,

    # Training length
    num_train_epochs=EPOCHS,
    warmup_steps=10,
    learning_rate=LEARNING_RATE,
    max_grad_norm=0.3,                   

    # Precision
    fp16=True,
    bf16=False,                          

    # Memory savers
    gradient_checkpointing=True,         # Trades compute for memory
    optim="paged_adamw_8bit",            # 8-bit optimizer saves ~400MB vs 32-bit
    dataloader_num_workers=0,            # Avoids multiprocessing memory issues

    # Logging & saving
    logging_steps=5,
    evaluation_strategy="steps",
    eval_steps=50,
    save_strategy="steps",
    save_steps=50,
    save_total_limit=2,                  # Keeping only best 2 checkpoints
    load_best_model_at_end=True,
    report_to="none",
)

# %%
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    formatting_func=formatting_func,
    max_seq_length=MAX_SEQ_LEN,
    args=training_args,
)
# Out:
# /home/abhin/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Map: 100%|██████████| 95/95 [00:00<00:00, 2741.71 examples/s]

# %%
if torch.cuda.is_available():
    allocated = torch.cuda.memory_allocated(0) / 1024**3
    reserved  = torch.cuda.memory_reserved(0) / 1024**3
    print(f"💾 VRAM before training: {allocated:.2f}GB allocated / {reserved:.2f}GB reserved")

print("🚀 Starting QLoRA fine-tuning...\n")
trainer.train()

print("\n💾 Saving adapters...")
trainer.model.save_pretrained(adapter_save_path)
tokenizer.save_pretrained(adapter_save_path)
print(f"  Adapters saved to: {adapter_save_path}")
# Out:
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# 💾 VRAM before training: 7.42GB allocated / 9.40GB reserved
# 🚀 Starting QLoRA fine-tuning...
# /home/abhin/.local/lib/python3.10/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='235' max='235' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [235/235 1:03:32, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.609900</td>
#       <td>0.530588</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.252300</td>
#       <td>0.289043</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.152800</td>
#       <td>0.257993</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.125900</td>
#       <td>0.252020</td>
#     </tr>
#   </tbody>
# </table><p>
# /home/abhin/.local/lib/python3.10/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /home/abhin/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/abhin/.local/lib/python3.10/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /home/abhin/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/abhin/.local/lib/python3.10/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /home/abhin/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/abhin/.local/lib/python3.10/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# 💾 Saving adapters...
# /home/abhin/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#   Adapters saved to: temp-adapters

# %%
print("\n🧹 Clearing VRAM for merge step...")
del model
del trainer
gc.collect()
torch.cuda.empty_cache()
# Out:
# 🧹 Clearing VRAM for merge step...

# %%
if torch.cuda.is_available():
    free = (torch.cuda.get_device_properties(0).total_memory
            - torch.cuda.memory_allocated(0)) / 1024**3
    print(f"  VRAM freed. Available: {free:.2f}GB")

print("\n🔄 Loading base model on CPU for merging...")
print("  (This uses ~16GB system RAM — may take a few minutes)")
# Out:
#   VRAM freed. Available: 6.00GB
#
# 🔄 Loading base model on CPU for merging...
#   (This uses ~16GB system RAM — may take a few minutes)

# %%
base_model = AutoModelForCausalLM.from_pretrained(
    model_name,max_memory=max_memory,
    low_cpu_mem_usage=True,
    torch_dtype=torch.float16,
    device_map="auto",              # Always merge on CPU to avoid OOM
)

print("🔗 Applying LoRA adapters...")
model_to_merge = PeftModel.from_pretrained(base_model, adapter_save_path)

print("⚙️  Merging weights (this takes a few minutes)...")
merged_model = model_to_merge.merge_and_unload()

print(f"✅ Saving merged model to: {merged_save_path}")
merged_model.save_pretrained(merged_save_path, safe_serialization=True)
tokenizer.save_pretrained(merged_save_path)

# Clean up CPU RAM
del base_model, model_to_merge, merged_model
gc.collect()
print("  Merged model saved successfully.\n")
# Out:
# /home/abhin/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 base_model = AutoModelForCausalLM.from_pretrained(
#       2     model_name,max_memory=max_memory,
#       3     low_cpu_mem_usage=True,
#       4     torch_dtype=torch.float16,
#       5     device_map="auto",              # Always merge on CPU to avoid OOM
#       6 )
#       8 print("🔗 Applying LoRA adapters...")
#       9 model_to_merge = PeftModel.from_pretrained(base_model, adapter_save_path)
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:563, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561 elif type(config) in cls._model_mapping.keys():
#     562     model_class = _get_model_class(config, cls._model_mapping)
# --> 563     return model_class.from_pretrained(
#     564         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565     )
#     566 raise ValueError(
#     567     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     568     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     569 )
#
# File ~/.local/lib/python3.10/site-packages/transformers/modeling_utils.py:3677, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3668     if dtype_orig is not None:
#    3669         torch.set_default_dtype(dtype_orig)
#    3670     (
#    3671         model,
#    3672         missing_keys,
#    3673         unexpected_keys,
#    3674         mismatched_keys,
#    3675         offload_index,
#    3676         error_msgs,
# -> 3677     ) = cls._load_pretrained_model(
#    3678         model,
#    3679         state_dict,
#    3680         loaded_state_dict_keys,  # XXX: rename?
#    3681         resolved_archive_file,
#    3682         pretrained_model_name_or_path,
#    3683         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    3684         sharded_metadata=sharded_metadata,
#    3685         _fast_init=_fast_init,
#    3686         low_cpu_mem_usage=low_cpu_mem_usage,
#    3687         device_map=device_map,
#    3688         offload_folder=offload_folder,
#    3689         offload_state_dict=offload_state_dict,
#    3690         dtype=torch_dtype,
#    3691         hf_quantizer=hf_quantizer,
#    3692         keep_in_fp32_modules=keep_in_fp32_modules,
#    3693     )
#    3695 # make sure token embedding weights are still tied if needed
#    3696 model.tie_weights()
#
# File ~/.local/lib/python3.10/site-packages/transformers/modeling_utils.py:4104, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules)
#    4100                 set_module_tensor_to_device(
#    4101                     model_to_load, key, "cpu", torch.empty(*param.size(), dtype=dtype)
#    4102                 )
#    4103     else:
# -> 4104         new_error_msgs, offload_index, state_dict_index = _load_state_dict_into_meta_model(
#    4105             model_to_load,
#    4106             state_dict,
#    4107             loaded_keys,
#    4108             start_prefix,
#    4109             expected_keys,
#    4110             device_map=device_map,
#    4111             offload_folder=offload_folder,
#    4112             offload_index=offload_index,
#    4113             state_dict_folder=state_dict_folder,
#    4114             state_dict_index=state_dict_index,
#    4115             dtype=dtype,
#    4116             hf_quantizer=hf_quantizer,
#    4117             is_safetensors=is_safetensors,
#    4118             keep_in_fp32_modules=keep_in_fp32_modules,
#    4119             unexpected_keys=unexpected_keys,
#    4120         )
#    4121         error_msgs += new_error_msgs
#    4122 else:
#
# File ~/.local/lib/python3.10/site-packages/transformers/modeling_utils.py:886, in _load_state_dict_into_meta_model(model, state_dict, loaded_state_dict_keys, start_prefix, expected_keys, device_map, offload_folder, offload_index, state_dict_folder, state_dict_index, dtype, hf_quantizer, is_safetensors, keep_in_fp32_modules, unexpected_keys)
#     875     state_dict_index = offload_weight(param, param_name, state_dict_folder, state_dict_index)
#     876 elif (
#     877     not is_quantized
#     878     or (not hf_quantizer.requires_parameters_quantization)
#    (...)
#     884 ):
#     885     # For backward compatibility with older versions of `accelerate` and for non-quantized params
# --> 886     set_module_tensor_to_device(model, param_name, param_device, **set_module_kwargs)
#     887 else:
#     888     hf_quantizer.create_quantized_param(model, param, param_name, param_device, state_dict, unexpected_keys)
#
# File ~/.local/lib/python3.10/site-packages/accelerate/utils/modeling.py:400, in set_module_tensor_to_device(module, tensor_name, device, value, dtype, fp16_statistics, tied_params_map)
#     398             module._parameters[tensor_name] = param_cls(new_value, requires_grad=old_value.requires_grad)
#     399 elif isinstance(value, torch.Tensor):
# --> 400     new_value = value.to(device)
#     401 else:
#     402     new_value = torch.tensor(value, device=device)
#
# File ~/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:302, in _lazy_init()
#     300 if "CUDA_MODULE_LOADING" not in os.environ:
#     301     os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 302 torch._C._cuda_init()
#     303 # Some of the queued calls may reentrantly call _lazy_init();
#     304 # we need to just return without initializing in that case.
#     305 # However, we must not let any *other* threads in!
#     306 _tls.is_initializing = True
#
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx

# %%
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# Successfully installed numpy-1.26.4
